# %%
import pandas as pd
import numpy as np
import pickle
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from sklearn.preprocessing import LabelBinarizer
import sklearn.datasets as skds
from pathlib import Path

# %%
data = pd.read_csv('/content/drive/MyDrive/Tweets.csv')
data
# Out:
#                  tweet_id  ...               user_timezone
# 0      570306133677760513  ...  Eastern Time (US & Canada)
# 1      570301130888122368  ...  Pacific Time (US & Canada)
# 2      570301083672813571  ...  Central Time (US & Canada)
# 3      570301031407624196  ...  Pacific Time (US & Canada)
# 4      570300817074462722  ...  Pacific Time (US & Canada)
# ...                   ...  ...                         ...
# 14635  569587686496825344  ...                         NaN
# 14636  569587371693355008  ...                         NaN
# 14637  569587242672398336  ...                         NaN
# 14638  569587188687634433  ...  Eastern Time (US & Canada)
# 14639  569587140490866689  ...                         NaN
#
# [14640 rows x 15 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g7l-gt4-kVsZlH9wujiNI9KA0AXd2fZbkP-mjyWuZj0iX-bpdLj0EQ
# Mounted at /content/drive

# %%
# lets take 80% data as training and remaining 20% for test.
train_size = int(len(data) * .8)
 
train_posts = data['text'][:train_size]
train_tags = data['airline_sentiment'][:train_size]

 
test_posts = data['text'][train_size:]
test_tags = data['airline_sentiment'][train_size:]

# %%
# 4 news groups
num_labels = 3
vocab_size = 15000
batch_size = 100
 
# define Tokenizer with Vocab Size
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_posts)
 
x_train = tokenizer.texts_to_matrix(train_posts, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_posts, mode='tfidf')
 
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))



model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

model.summary()
 
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=45,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               7680512
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# _________________________________________________________________
# activation_3 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 7,845,123
# Trainable params: 7,845,123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/45
# 106/106 [==============================] - 4s 10ms/step - loss: 0.7953 - accuracy: 0.6412 - val_loss: 0.3974 - val_accuracy: 0.8515
# Epoch 2/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.2645 - accuracy: 0.9081 - val_loss: 0.4420 - val_accuracy: 0.8422
# Epoch 3/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0883 - accuracy: 0.9757 - val_loss: 0.5995 - val_accuracy: 0.8447
# Epoch 4/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0397 - accuracy: 0.9877 - val_loss: 0.8723 - val_accuracy: 0.8362
# Epoch 5/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0237 - accuracy: 0.9933 - val_loss: 0.9908 - val_accuracy: 0.8328
# Epoch 6/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 1.0744 - val_accuracy: 0.8319
# Epoch 7/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 1.1992 - val_accuracy: 0.8302
# Epoch 8/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 1.1654 - val_accuracy: 0.8328
# Epoch 9/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 1.2292 - val_accuracy: 0.8268
# Epoch 10/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 1.2757 - val_accuracy: 0.8259
# Epoch 11/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0147 - accuracy: 0.9968 - val_loss: 1.3123 - val_accuracy: 0.8114
# Epoch 12/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 1.3813 - val_accuracy: 0.8242
# Epoch 13/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 1.3366 - val_accuracy: 0.8251
# Epoch 14/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 1.4131 - val_accuracy: 0.8319
# Epoch 15/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0113 - accuracy: 0.9972 - val_loss: 1.3063 - val_accuracy: 0.8319
# Epoch 16/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 1.1762 - val_accuracy: 0.8148
# Epoch 17/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0175 - accuracy: 0.9939 - val_loss: 1.2142 - val_accuracy: 0.8166
# Epoch 18/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 1.2329 - val_accuracy: 0.8217
# Epoch 19/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 1.5058 - val_accuracy: 0.8089
# Epoch 20/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 1.5099 - val_accuracy: 0.8063
# Epoch 21/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0218 - accuracy: 0.9958 - val_loss: 1.4213 - val_accuracy: 0.8080
# Epoch 22/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 1.5643 - val_accuracy: 0.8097
# Epoch 23/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 1.5904 - val_accuracy: 0.8012
# Epoch 24/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 1.5795 - val_accuracy: 0.8234
# Epoch 25/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 1.6211 - val_accuracy: 0.8038
# Epoch 26/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 1.6440 - val_accuracy: 0.8114
# Epoch 27/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 1.5672 - val_accuracy: 0.8106
# Epoch 28/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 1.6116 - val_accuracy: 0.8183
# Epoch 29/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 1.7933 - val_accuracy: 0.8140
# Epoch 30/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 1.7566 - val_accuracy: 0.8063
# Epoch 31/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 1.8933 - val_accuracy: 0.8183
# Epoch 32/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 1.8227 - val_accuracy: 0.8123
# Epoch 33/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 1.8618 - val_accuracy: 0.8131
# Epoch 34/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 2.0468 - val_accuracy: 0.8251
# Epoch 35/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 2.1143 - val_accuracy: 0.8123
# Epoch 36/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 1.9861 - val_accuracy: 0.8234
# Epoch 37/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 1.7488 - val_accuracy: 0.7952
# Epoch 38/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 1.6878 - val_accuracy: 0.8225
# Epoch 39/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0178 - accuracy: 0.9974 - val_loss: 1.8400 - val_accuracy: 0.7696
# Epoch 40/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 1.8489 - val_accuracy: 0.8063
# Epoch 41/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 1.7602 - val_accuracy: 0.8294
# Epoch 42/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 1.7668 - val_accuracy: 0.8140
# Epoch 43/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 1.9730 - val_accuracy: 0.8200
# Epoch 44/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 1.9105 - val_accuracy: 0.8123
# Epoch 45/45
# 106/106 [==============================] - 1s 7ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 2.0194 - val_accuracy: 0.8242

# %%
score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)

print('Test accuracy:', score[1])
print(score)
text_labels = encoder.classes_
print(text_labels)
for i in range(10):
    prediction = model.predict(np.array([x_test[i]]))
    predicted_label = text_labels[np.argmax(prediction[0])]
    print(predicted_label)
    print(test_posts.iloc[i])
    print(prediction)
    print('Actual label:' + test_tags.iloc[i])
    print("Predicted label: " + predicted_label)
# Out:
# 30/30 [==============================] - 0s 5ms/step - loss: 2.3345 - accuracy: 0.7753
# Test accuracy: 0.7752732038497925
# [2.3344595432281494, 0.7752732038497925]
# ['negative' 'neutral' 'positive']
# negative
# @USAirways wow this airline is a joke, absolutely horrendous customer service. you guys should be ashamed.
# [[1.000000e+00 7.803154e-21 4.072090e-21]]
# Actual label:negative
# Predicted label: negative
# negative
# @USAirways Flight Cancelled Flighted because of #Neptune Could not get to my destination. #notmyfault  #waive$200fee #ripoff #poorcustomerservice
# [[1.0000000e+00 1.7710628e-21 2.9822382e-23]]
# Actual label:negative
# Predicted label: negative
# positive
# @USAirways YOU ARE THE BEST AIRWAYS! Follow me please!!!!!🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏
# [[6.4841028e-05 1.5895093e-02 9.8404008e-01]]
# Actual label:positive
# Predicted label: positive
# negative
# @USAirways  If you can waive a fee at time of Cancelled Flightation, you CAN WAIVE IT AT A FUTURE DATE! #usairways #ripoff #poorcustomerservice
# [[9.9910635e-01 8.9356990e-04 3.8570269e-10]]
# Actual label:negative
# Predicted label: negative
# negative
# @USAirways flight #654 sitting at JFK with delays for 3-1/2 hrs! No employees to load bags? #terrible
# [[1.0000000e+00 2.6687071e-15 2.8625622e-20]]
# Actual label:negative
# Predicted label: negative
# negative
# @USAirways I have been rebooked but It has been handled very unprofessionally. Cancelled Flightations happen but the disorganization is uncalled for.
# [[1.0000000e+00 6.0643912e-09 1.3184774e-08]]
# Actual label:negative
# Predicted label: negative
# negative
# @USAirways conf number FMJTYL delayed - any chance of getting an earlier flight fll to phx?
# [[8.4866148e-01 1.5132567e-01 1.2874554e-05]]
# Actual label:neutral
# Predicted label: negative
# negative
# @USAirways I have now called 12 times in the last three days. That's unacceptable. I'm willing to wait on hold, but that's not an option.
# [[1.0000000e+00 9.3117110e-24 3.0635145e-25]]
# Actual label:negative
# Predicted label: negative
# positive
# @USAirways YOU ARE AMAZING!!! YOU ARE THE BEST!!! FOLLOW ME PLEASE AND I FOLLOW YOU BACK;)🙏🙏🙏✌️😉)
# [[3.3597480e-12 1.3253802e-09 1.0000000e+00]]
# Actual label:positive
# Predicted label: positive
# negative
# @USAirways I've been on hold for over 2 hours. Need to re-book a flight, please help.
# [[9.9999917e-01 8.5867003e-07 3.9494790e-08]]
# Actual label:negative
# Predicted label: negative

# %%
# creates a HDF5 file 'my_model.h5'
model = model.save('my_model.h5')
 
# Save Tokenizer i.e. Vocabulary
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# load our saved model
from keras.models import load_model
model = load_model('my_model.h5')
 
# load tokenizer
tokenizer = Tokenizer()
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
    
    
encoder.classes_ #LabelBinarizer
# Out:
# array(['negative', 'neutral', 'positive'], dtype='<U8')

# %%
# These are the labels we stored from our training
# The order is very important here.
 
labels = np.array(['negative', 'neutral', 'positive'])
 
test_files = ["/content/sentiment .txt"]
x_data = []
for t_f in test_files:
    t_f_data = Path(t_f).read_text()
    x_data.append(t_f_data)
 
x_data_series = pd.Series(x_data)
x_tokenized = tokenizer.texts_to_matrix(x_data_series, mode='tfidf')
 
i=0
for x_t in x_tokenized:
    prediction = model.predict(np.array([x_t]))
    predicted_label = labels[np.argmax(prediction[0])]
    print(prediction)
    print("File ->", test_files[i], "Predicted label: " + predicted_label)
# Out:
# [[3.1766616e-04 2.5070757e-02 9.7461164e-01]]
# File -> /content/sentiment .txt Predicted label: positive

# %%
p = []
predicted_percentage = prediction*100
for i in range(3):
  p.append(predicted_percentage[0][i])
  p

# %%
import plotly.graph_objects as go
labels = ['negative', 'neutral', 'positive']
fig = go.Figure(go.Bar(x=labels,y=p))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ad6b3f52-3860-420c-a529-47ad545c4502" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad6b3f52-3860-420c-a529-47ad545c4502")) {
#                     Plotly.newPlot(
#                         'ad6b3f52-3860-420c-a529-47ad545c4502',
#                         [{"type": "bar", "x": ["negative", "neutral", "positive"], "y": [0.0317666158080101, 2.507075786590576, 97.46116638183594]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
